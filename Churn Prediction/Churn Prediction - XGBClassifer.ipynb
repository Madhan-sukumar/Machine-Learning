# %% [markdown]
# ## Importing Packages

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import balanced_accuracy_score,roc_auc_score,make_scorer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# %% [markdown]
# ## Import the data

# %%
df = pd.read_csv("./Telco_customer_churn.csv")

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
#checking the shape
df.shape
# Out:
# (7043, 33)

# %% [markdown]
# ## Data Preprocessing

# %%
# now dropping the last four columns since its not useful

df.drop(['Churn Label','Churn Score','CLTV','Churn Reason'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...
#
#   Device Protection Tech Support Streaming TV  Streaming Movies  \
# 0                No           No           No                No
# ...

# %%
df.shape
# Out:
# (7043, 29)

# %% [markdown]
# <b>Note</b> The columns Count,Country,State has only one unique values and since it is not useful, so dropping the mentioned three columns, whereas the city column contains different values, so leaving as it is and dropping the lat Long column as well.

# %%
print(df['Count'].unique())
print(df['Country'].unique())
print(df['State'].unique())
print(df['City'].unique())
# Out:
# [1]
# ['United States']
# ['California']
# ['Los Angeles' 'Beverly Hills' 'Huntington Park' ... 'Standish' 'Tulelake'
#  'Olympic Valley']

# %%
df.drop(['Count','Country','State','CustomerID','Lat Long'],axis=1,inplace=True)

# %%
df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %%
#replacing blank space in city column with underscore

df['City'].replace(' ','_',regex=True,inplace=True)
df.head()
# Out:
#           City  Zip Code   Latitude   Longitude  Gender Senior Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service  ... Device Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# ...

# %%
df['City'].unique()[0:10]
# Out:
# array(['Los_Angeles', 'Beverly_Hills', 'Huntington_Park', 'Lynwood',
#        'Marina_Del_Rey', 'Inglewood', 'Santa_Monica', 'Torrance',
#        'Whittier', 'La_Habra'], dtype=object)

# %%
# now eliminating the whitespaces in column names

df.columns = df.columns.str.replace(' ','_')
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %% [markdown]
# ### Handling Missing Data

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               7043 non-null   object
#  1   Zip_Code           7043 non-null   int64
#  2   Latitude           7043 non-null   float64
#  3   Longitude          7043 non-null   float64
#  4   Gender             7043 non-null   object
#  5   Senior_Citizen     7043 non-null   object
#  6   Partner            7043 non-null   object
#  7   Dependents         7043 non-null   object
#  8   Tenure_Months      7043 non-null   int64
#  9   Phone_Service      7043 non-null   object
#  10  Multiple_Lines     7043 non-null   object
#  11  Internet_Service   7043 non-null   object
#  12  Online_Security    7043 non-null   object
#  13  Online_Backup      7043 non-null   object
#  14  Device_Protection  7043 non-null   object
#  15  Tech_Support       7043 non-null   object
# ...

# %%
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %% [markdown]
# The column`Total_charges` datatype is object, whereas it has not only numbers,not text, but the object datatype shows that it contains more than numbers in it.

# %%
# it seems there is no null value
df['Total_Charges'].isnull().sum()
# Out:
# 0

# %%
#printing the missing value rows
df.loc[df['Total_Charges']==' ']
# Out:
#                 City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 2234  San_Bernardino     92408  34.084909 -117.258107  Female             No
# 2438    Independence     93526  36.869584 -118.189241    Male             No
# 2568       San_Mateo     94401  37.590421 -122.306467  Female             No
# 2667       Cupertino     95014  37.306612 -122.080621    Male             No
# 2856        Redcrest     95569  40.363446 -123.835041  Female             No
# 4331     Los_Angeles     90029  34.089953 -118.294824    Male             No
# 4687        Sun_City     92585  33.739412 -117.173334    Male             No
# 5104      Ben_Lomond     95005  37.078873 -122.090386  Female             No
# 5719        La_Verne     91750  34.144703 -117.770299    Male             No
# 6772            Bell     90201  33.970343 -118.171368  Female             No
# 6840      Wilmington     90744  33.782068 -118.262263    Male             No
#
# ...

# %%
#we having 11 missing values in them, which means data is missing.
len(df.loc[df['Total_Charges']==' '])
# Out:
# 11

# %%
df.loc[(df['Total_Charges']==' '),'Total_Charges']=0

# %%
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %%
#still total_charges column as object
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges         object
# Churn_Value            int64
# dtype: object

# %%
#converting total charges object column into numeric
df['Total_Charges'] = pd.to_numeric(df['Total_Charges'])

# %%
df.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# Churn_Value            int64
# dtype: object

# %% [markdown]
#  > Now replacing all the whitespaces in all of the columns with underscores

# %%
df.replace(' ','_',regex=True,inplace=True)

# %%
df.head()
# Out:
#           City  Zip_Code   Latitude   Longitude  Gender Senior_Citizen  \
# 0  Los_Angeles     90003  33.964131 -118.272783    Male             No
# 1  Los_Angeles     90005  34.059281 -118.307420  Female             No
# 2  Los_Angeles     90006  34.048013 -118.293953  Female             No
# 3  Los_Angeles     90010  34.062125 -118.315709  Female             No
# 4  Los_Angeles     90015  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure_Months Phone_Service  ... Device_Protection  \
# 0      No         No              2           Yes  ...                No
# 1      No        Yes              2           Yes  ...                No
# 2      No        Yes              8           Yes  ...               Yes
# 3     Yes        Yes             28           Yes  ...               Yes
# 4      No        Yes             49           Yes  ...               Yes
#
#   Tech_Support Streaming_TV Streaming_Movies        Contract  \
# ...

# %% [markdown]
# ## Splitting the Dataset

# %%
X = df.drop('Churn_Value',axis=1).copy()
y = df['Churn_Value'].copy()

# %%
X.shape
# Out:
# (7043, 23)

# %%
y.shape
# Out:
# (7043,)

# %% [markdown]
# ## Encoding the Categorical Values

# %%
X.dtypes
# Out:
# City                  object
# Zip_Code               int64
# Latitude             float64
# Longitude            float64
# Gender                object
# Senior_Citizen        object
# Partner               object
# Dependents            object
# Tenure_Months          int64
# Phone_Service         object
# Multiple_Lines        object
# Internet_Service      object
# Online_Security       object
# Online_Backup         object
# Device_Protection     object
# Tech_Support          object
# Streaming_TV          object
# Streaming_Movies      object
# Contract              object
# Paperless_Billing     object
# Payment_Method        object
# Monthly_Charges      float64
# Total_Charges        float64
# dtype: object

# %%
encoded_X = pd.get_dummies(X, columns=['City','Gender','Senior_Citizen','Partner','Dependents','Phone_Service',
                                        'Multiple_Lines','Internet_Service','Online_Security',
                                       'Online_Backup','Device_Protection',
                                        'Tech_Support','Streaming_TV','Streaming_Movies',
                                       'Contract','Paperless_Billing','Payment_Method'])

# %%
encoded_X.head()
# Out:
#    Zip_Code   Latitude   Longitude  Tenure_Months  Monthly_Charges  \
# 0     90003  33.964131 -118.272783              2            53.85
# 1     90005  34.059281 -118.307420              2            70.70
# 2     90006  34.048013 -118.293953              8            99.65
# 3     90010  34.062125 -118.315709             28           104.80
# 4     90015  34.039224 -118.266293             49           103.70
#
#    Total_Charges  City_Acampo  City_Acton  City_Adelanto  City_Adin  ...  \
# 0         108.15            0           0              0          0  ...
# 1         151.65            0           0              0          0  ...
# 2         820.50            0           0              0          0  ...
# 3        3046.05            0           0              0          0  ...
# 4        5036.30            0           0              0          0  ...
#
#    Streaming_Movies_Yes  Contract_Month-to-month  Contract_One_year  \
# ...

# %%
y.unique()
# Out:
# array([1, 0], dtype=int64)

# %% [markdown]
# ## Splitting the data for Training and Testing

# %%
df.groupby('Churn_Value').mean()
# Out:
#                  Zip_Code   Latitude   Longitude  Tenure_Months  \
# Churn_Value
# 0            93518.212215  36.287436 -119.804838      37.569965
# 1            93532.352595  36.268614 -119.782388      17.979133
#
#              Monthly_Charges  Total_Charges
# Churn_Value
# 0                  61.265124    2549.911442
# 1                  74.441332    1531.796094

# %%
X_train,X_test,y_train,y_test = train_test_split(encoded_X,y,stratify=y,random_state=42)

# %%
xgb_model = xgb.XGBClassifier(objective='binary:logistic',missing=None,seed=42)

xgb_model.fit(X_train,y_train,verbose=True,early_stopping_rounds=10,eval_metric='aucpr',eval_set=[(X_test,y_test)])
# Out:
# [0]	validation_0-aucpr:0.64036
# [1]	validation_0-aucpr:0.64404
# [2]	validation_0-aucpr:0.65124
# [3]	validation_0-aucpr:0.65051
# [4]	validation_0-aucpr:0.65321
# [5]	validation_0-aucpr:0.64854
# [6]	validation_0-aucpr:0.65459
# [7]	validation_0-aucpr:0.65895
# [8]	validation_0-aucpr:0.65746
# [9]	validation_0-aucpr:0.65850
# [10]	validation_0-aucpr:0.66217
# [11]	validation_0-aucpr:0.66527
# [12]	validation_0-aucpr:0.66322
# [13]	validation_0-aucpr:0.66310
# [14]	validation_0-aucpr:0.66000
# [15]	validation_0-aucpr:0.66027
# [16]	validation_0-aucpr:0.65781
# [17]	validation_0-aucpr:0.65593
# [18]	validation_0-aucpr:0.65738
# [19]	validation_0-aucpr:0.65829
# [20]	validation_0-aucpr:0.65683
# [21]	validation_0-aucpr:0.65707
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
# ...

# %%
# after finding out the correct parameter values

clf_xgb = xgb.XGBClassifier( gamma=0.25, learning_rate=0.1, max_depth=4,
          reg_lambda=10, scale_pos_weight=3, seed=42,
       subsample=0.9,objective='binary:logistic',colsample_bytree=0.5)

clf_xgb.fit(X_train,y_train,verbose=True,early_stopping_rounds=20,eval_metric='aucpr',eval_set=[(X_test,y_test)])
# Out:
# [0]	validation_0-aucpr:0.56622
# [1]	validation_0-aucpr:0.59525
# [2]	validation_0-aucpr:0.62515
# [3]	validation_0-aucpr:0.62633
# [4]	validation_0-aucpr:0.63192
# [5]	validation_0-aucpr:0.63171
# [6]	validation_0-aucpr:0.62947
# [7]	validation_0-aucpr:0.63056
# [8]	validation_0-aucpr:0.63608
# [9]	validation_0-aucpr:0.63616
# [10]	validation_0-aucpr:0.63627
# [11]	validation_0-aucpr:0.65626
# [12]	validation_0-aucpr:0.65366
# [13]	validation_0-aucpr:0.65374
# [14]	validation_0-aucpr:0.65623
# [15]	validation_0-aucpr:0.64859
# [16]	validation_0-aucpr:0.64615
# [17]	validation_0-aucpr:0.64529
# [18]	validation_0-aucpr:0.64527
# [19]	validation_0-aucpr:0.65224
# [20]	validation_0-aucpr:0.64951
# [21]	validation_0-aucpr:0.65017
# [22]	validation_0-aucpr:0.65047
# [23]	validation_0-aucpr:0.64627
# [24]	validation_0-aucpr:0.64897
# [25]	validation_0-aucpr:0.65336
# [26]	validation_0-aucpr:0.65277
# [27]	validation_0-aucpr:0.65297
# [28]	validation_0-aucpr:0.65410
# ...

# %%
plot_confusion_matrix(clf_xgb,X_test,y_test,values_format='d',display_labels=['Continuing','Left'])
